# %% [markdown]
# # Name: Moinuddin Farooqui
# # Cureya Task 2

# %% [markdown]
# ## Importing The Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("/content/50_Startups (2).csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
sns.barplot(x='State',y='Profit',data=df, palette="PuBuGn_r")

# %%
dummy = pd.get_dummies(df["State"])
encd_data = pd.concat([dummy, df], axis=1)
encd_data.drop(['State'], inplace=True, axis=1)
encd_data.head()
# Out:
#    California  Florida  New York  ...  Administration  Marketing Spend     Profit
# 0           0        0         1  ...       136897.80        471784.10  192261.83
# 1           1        0         0  ...       151377.59        443898.53  191792.06
# 2           0        1         0  ...       101145.55        407934.54  191050.39
# 3           0        0         1  ...       118671.85        383199.62  182901.99
# 4           0        1         0  ...        91391.77        366168.42  166187.94
#
# [5 rows x 7 columns]

# %%
sns.heatmap(df.corr(),annot=True)

# %%
x=df[['R&D Spend', 'Administration', 'Marketing Spend']]
y=df["Profit"]

# %% [markdown]
# ## EDA on given data

# %%
plt.scatter(x['R&D Spend'],y,color='y',marker='*')

# %%
plt.scatter(x['Administration'],y,color='g',marker='+')

# %%
plt.scatter(x['Marketing Spend'],y,color='b',marker='o')

# %%
sns.pairplot(df)

# %% [markdown]
# ##Splitting data in train test split

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## Training the Model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Prediction

# %%
ypred=model.predict(xtest)

# %%
model.score(xtest,ytest)
# Out:
# 0.9494360987507664

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9480587012555666

# %% [markdown]
# ## Comparison

# %%
pd.DataFrame({'Actual':ytest,'Prediction':ypred})
# Out:
#        Actual     Prediction
# 17  125370.37  131746.360591
# 22  110352.25  115475.826106
# 42   71498.49   70146.991197
# 9   149759.96  156153.778313
# 7   155752.60  162126.469184
# 13  134307.35  128825.133306
# 14  132602.65  151747.743409
# 40   78239.91   74856.266454
# 1   191792.06  191823.192975
# 26  105733.54  111913.181542
